# %%
def build_uschema_from_testdata(df):
    """
    Convert test dataset (columns: omop, table, label)
    into a full U-Schema model with unique entities & attributes.
    """
    entities = {}

    for _, row in df.iterrows():
        omop = row["table"]

        # Split into tokens
        parts = [p.strip().lower() for p in omop.split("-") if p.strip()]

        entity = parts[0]
        attrs = parts[1:]  # may contain multiple attributes

        if entity not in entities:
            entities[entity] = set()

        # Add attributes (unique)
        for a in attrs:
            entities[entity].add(a)

    # --- build final U-Schema ---
    uschema_entities = []

    for entity, attrs in entities.items():
        uschema_entities.append({
            "EntityType": {
                "name": entity,
                "variations": [
                    {
                        "StructuralVariation": {
                            "properties": [
                                {
                                    "Attribute": [
                                        {
                                            "name": attr,
                                            "type": "string"
                                        }
                                        for attr in sorted(attrs)
                                    ]
                                }
                            ]
                        }
                    }
                ]
            }
        })

    return {
        "uSchemaModel": {
            "entities": uschema_entities
        }
    }

# %%
import pandas as pd
df= pd.read_excel("omop_mimic_data.xlsx")
schema_mimic = build_uschema_from_testdata(df)
schema_mimic
# Out:
# {'uSchemaModel': {'entities': [{'EntityType': {'name': 'admissions',
#      'variations': [{'StructuralVariation': {'properties': [{'Attribute': [{'name': 'admission_location',
#             'type': 'string'},
#            {'name': 'admission_type', 'type': 'string'},
#            {'name': 'admittime', 'type': 'string'},
#            {'name': 'deathtime', 'type': 'string'},
#            {'name': 'diagnosis', 'type': 'string'},
#            {'name': 'dischtime', 'type': 'string'},
#            {'name': 'edouttime', 'type': 'string'},
#            {'name': 'edregtime', 'type': 'string'},
#            {'name': 'ethnicity', 'type': 'string'},
#            {'name': 'hadm_id', 'type': 'string'},
#            {'name': 'hospital_expire_flag', 'type': 'string'},
#            {'name': 'insurance', 'type': 'string'},
#            {'name': 'language', 'type': 'string'},
#            {'name': 'marital_status', 'type': 'string'},
#            {'name': 'religion', 'type': 'string'},
# ...

# %%
import json
with open("mimic-schema.json", "w") as f:
    json.dump(schema_mimic, f, indent=2)
print("U-Schema model saved to mimic-schema.json")
# Out:
# U-Schema model saved to mimic-schema.json

# %%
import pandas as pd
df = pd.read_excel("omop_mimic_data.xlsx")

uschema_json = build_uschema_from_testdata(df)

# %%
uschema_json
# Out:
# {'uSchemaModel': {'entities': [{'EntityType': {'name': 'person',
#      'variations': [{'StructuralVariation': {'properties': [{'Attribute': [{'name': 'birth_datetime',
#             'type': 'string'},
#            {'name': 'care_site_id', 'type': 'string'},
#            {'name': 'day_of_birth', 'type': 'string'},
#            {'name': 'death_datetime', 'type': 'string'},
#            {'name': 'ethnicity_concept_id', 'type': 'string'},
#            {'name': 'ethnicity_source_concept_id', 'type': 'string'},
#            {'name': 'ethnicity_source_value', 'type': 'string'},
#            {'name': 'gender_concept_id', 'type': 'string'},
#            {'name': 'gender_source_concept_id', 'type': 'string'},
#            {'name': 'gender_source_value', 'type': 'string'},
#            {'name': 'location_id', 'type': 'string'},
#            {'name': 'month_of_birth', 'type': 'string'},
#            {'name': 'person_id', 'type': 'string'},
# ...

# %%
import json

output_path = "uschema_testdata.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(uschema_json, f, ensure_ascii=False, indent=2)

print(f"U-Schema saved to {output_path}")
# Out:
# U-Schema saved to uschema_testdata.json

# %%
import json
import pandas as pd
from pathlib import Path

# ============================================================
# 1. FICHIERS
# ============================================================

EXCEL_FILE = "omop_mimic_data.xlsx"
INPUT_JSON = "mimiciii_schema_from_table.json"
OUTPUT_JSON = "mimici_schema.json"


# ============================================================
# 2. CHARGER LES DONNÉES
# ============================================================

df = pd.read_excel(EXCEL_FILE)

with open(INPUT_JSON, "r", encoding="utf-8") as f:
    schema = json.load(f)


# ============================================================
# 3. CONSTRUIRE UN INDEX DES DESCRIPTIONS
# ============================================================
#
# La colonne "table" contient par exemple :
#
# admissions-row_id
# admissions-subject_id
# admissions-hadm_id
#
# On récupère des1 et des2 associés à cette valeur.
#
# ============================================================

description_index = {}

for _, row in df.iterrows():

    table_column = str(row["table"]).strip()

    des1 = row.get("des1")
    des2 = row.get("des2")

    # Convertir NaN en None
    if pd.isna(des1):
        des1 = None

    if pd.isna(des2):
        des2 = None

    # Si plusieurs lignes existent pour la même colonne,
    # on conserve les descriptions non vides.
    if table_column not in description_index:
        description_index[table_column] = {
            "des1": des1,
            "des2": des2
        }
    else:

        if description_index[table_column]["des1"] is None and des1 is not None:
            description_index[table_column]["des1"] = des1

        if description_index[table_column]["des2"] is None and des2 is not None:
            description_index[table_column]["des2"] = des2


# ============================================================
# 4. AJOUTER LES DESCRIPTIONS AU JSON
# ============================================================

for table in schema["tables"]:

    table_name = table["name"]

    for column in table["columns"]:

        column_name = column["name"]

        # Reconstituer exactement la clé présente dans Excel
        table_column_key = f"{table_name}-{column_name}"

        descriptions = description_index.get(
            table_column_key,
            {"des1": None, "des2": None}
        )

        # Ajouter les descriptions
        column["description"] = descriptions["des1"]
        column["description_2"] = descriptions["des2"]


# ============================================================
# 5. SAUVEGARDER
# ============================================================

with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
    json.dump(
        schema,
        f,
        indent=2,
        ensure_ascii=False
    )

print("JSON créé avec succès :")
print(OUTPUT_JSON)
# Out:
# JSON créé avec succès :
# mimici_schema.json
